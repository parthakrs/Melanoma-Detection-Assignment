# %% [markdown]
# # Problem statement:
#
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.
#
# The dataset consists of 2357 images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC). All images were sorted according to the classification taken with ISIC, and all subsets were divided into the same number of images, with the exception of melanomas and moles, whose images are slightly dominant.
#
# The data set contains the following diseases:
#
# * Actinic keratosis
# * Basal cell carcinoma
# * Dermatofibroma
# * Melanoma
# * Nevus
# * Pigmented benign keratosis
# * Seborrheic keratosis
# * Squamous cell carcinoma
# * Vascular lesion
#
# Build a multiclass classification model using a custom convolutional neural network in TensorFlow.

# %%
#Importing all the important libraries
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, cv2
import PIL
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Reading/Data Understanding
#
# Defining the path for train and test images
#
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
#unzip the dataset
# !unzip "/content/gdrive/MyDrive/SkinCancerDataset.zip" > /dev/null

# %%
# Importing Skin Cancer Data
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
data_dir_test = pathlib.Path("/content/Skin cancer ISIC The International Skin Imaging Collaboration/Test/")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
# Out:
# 2239

# %%
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 118

# %%
# Define some parameters for the loader
batch_size = 32
img_height = 180
img_width = 180

# %%
# Out:
# PosixPath('https:/drive.google.com/drive/folders/1M2eH8W26dkYz00nbPSWsTdRhUvVhPwvY?usp=drive_link')

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
# Loading the training data
# using seed=123 while creating dataset using tf.keras.preprocessing.image_dataset_from_directory
# resizing images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                               seed=123,
                                                               validation_split=0.2,
                                                               image_size=(img_height,img_width),
                                                               batch_size=batch_size,
                                                               color_mode='rgb',
                                                               subset='training')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
# Loading the validation data
# using seed=123 while creating dataset using tf.keras.preprocessing.image_dataset_from_directory
# resizing images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                             seed=123,
                                                             validation_split=0.2,
                                                             image_size=(img_height,img_width),
                                                             batch_size=batch_size,
                                                             color_mode='rgb',
                                                             subset='validation')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# Loading the testing data
# using seed=123 while creating dataset using tf.keras.preprocessing.image_dataset_from_directory
# resizing images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_test,
                                                             seed=123,
                                                             image_size=(img_height,img_width),
                                                             batch_size=batch_size,
                                                             color_mode='rgb')
# Out:
# Found 118 files belonging to 9 classes.

# %%
# Listing out all the classes of skin cancer and store them in a list.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# # Dataset visualisation
#
# Creating a code to visualize one instance of all the nine classes present in the dataset

# %%
image = plt.imread((list(data_dir_train.glob(class_names[0]+'/*.jpg'))[0]))
plt.imshow(image)

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(25,8))
for i in range(len(class_names)):
  plt.subplot(2,5,i+1)
  image= plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %%
# Configure the dataset for performance

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.\
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
# Method to create plots of the loss and accuracy on the training and validation sets:
def plot_cnn_metrics(history,epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %% [markdown]
# # Model Building & training :
#
# * Creating a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescaling images to normalize pixel values between (0,1).
# * Choosing an appropriate optimiser and loss function for model training
# * Training the model for ~20 epochs
# * Plotting Graph for findings after the model fit to check if there is any evidence of model overfit or underfit.

# %%
# CNN Model
model=models.Sequential()
# scaling the pixel values from 0-255 to 0-1
model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))

# Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

# Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(9,activation='softmax'))

# %%
# Compiling the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 259200)            0
#
#  dense (Dense)               (None, 256)               66355456
#
#  dense_1 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 66433417 (253.42 MB)
# Trainable params: 66433417 (253.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Training the model
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 23s 141ms/step - loss: 2.6030 - accuracy: 0.3588 - val_loss: 1.8134 - val_accuracy: 0.3915
# Epoch 2/20
# 56/56 [==============================] - 4s 73ms/step - loss: 1.4578 - accuracy: 0.4855 - val_loss: 1.4407 - val_accuracy: 0.5123
# Epoch 3/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.3560 - accuracy: 0.5329 - val_loss: 1.3606 - val_accuracy: 0.5615
# Epoch 4/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.2264 - accuracy: 0.5781 - val_loss: 1.5507 - val_accuracy: 0.5168
# Epoch 5/20
# 56/56 [==============================] - 4s 72ms/step - loss: 1.1565 - accuracy: 0.5988 - val_loss: 1.4293 - val_accuracy: 0.5123
# Epoch 6/20
# 56/56 [==============================] - 4s 70ms/step - loss: 0.9931 - accuracy: 0.6551 - val_loss: 1.4422 - val_accuracy: 0.5213
# Epoch 7/20
# 56/56 [==============================] - 4s 70ms/step - loss: 0.8994 - accuracy: 0.6908 - val_loss: 1.7563 - val_accuracy: 0.5056
# Epoch 8/20
# 56/56 [==============================] - 4s 72ms/step - loss: 0.7462 - accuracy: 0.7377 - val_loss: 1.6569 - val_accuracy: 0.5347
# Epoch 9/20
# 56/56 [==============================] - 4s 70ms/step - loss: 0.6370 - accuracy: 0.7807 - val_loss: 1.6511 - val_accuracy: 0.5101
# Epoch 10/20
# 56/56 [==============================] - 4s 70ms/step - loss: 0.5915 - accuracy: 0.7930 - val_loss: 1.9533 - val_accuracy: 0.5101
# Epoch 11/20
# 56/56 [==============================] - 4s 72ms/step - loss: 0.4836 - accuracy: 0.8253 - val_loss: 2.0848 - val_accuracy: 0.5034
# Epoch 12/20
# 56/56 [==============================] - 4s 70ms/step - loss: 0.4158 - accuracy: 0.8560 - val_loss: 2.1017 - val_accuracy: 0.5078
# Epoch 13/20
# 56/56 [==============================] - 4s 71ms/step - loss: 0.3700 - accuracy: 0.8750 - val_loss: 1.9368 - val_accuracy: 0.5280
# Epoch 14/20
# 56/56 [==============================] - 4s 73ms/step - loss: 0.3538 - accuracy: 0.8594 - val_loss: 2.1005 - val_accuracy: 0.5481
# Epoch 15/20
# 56/56 [==============================] - 4s 71ms/step - loss: 0.2799 - accuracy: 0.8945 - val_loss: 2.3277 - val_accuracy: 0.5369
# Epoch 16/20
# 56/56 [==============================] - 4s 71ms/step - loss: 0.2445 - accuracy: 0.9029 - val_loss: 2.2748 - val_accuracy: 0.5213
# Epoch 17/20
# 56/56 [==============================] - 4s 74ms/step - loss: 0.2014 - accuracy: 0.9163 - val_loss: 2.2520 - val_accuracy: 0.5280
# Epoch 18/20
# 56/56 [==============================] - 4s 71ms/step - loss: 0.2024 - accuracy: 0.9169 - val_loss: 2.5735 - val_accuracy: 0.5302
# Epoch 19/20
# 56/56 [==============================] - 4s 71ms/step - loss: 0.2921 - accuracy: 0.8867 - val_loss: 2.8538 - val_accuracy: 0.4966
# Epoch 20/20
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2351 - accuracy: 0.9012 - val_loss: 2.5590 - val_accuracy: 0.5302

# %%
# Visualizing training results
plot_cnn_metrics(history,epochs)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <span style='font-family:Georgia'>
#         <b>Findings : </b>
#         <ol>
#             <li>As the training accuracy increases linearly over time, where as the validation accuracy stall at 50% accuracy in training process.</li>
#             <li>As the training loss dereases with epochs the validation loss increases.</li>
#             <li>The plots show that training accuracy and validation accuracy are off by large margins, and the model has achieved around <b>50%</b> accuracy on the validation set.</li>
#             <li>The difference in accuracy between training and validation accuracy is <b>noticeable</b> which is a sign of overfitting.</li>
#         </ol>
#     </span>
# </div>

# %% [markdown]
# # Choosing an appropriate data augmentation strategy to resolve underfitting/overfitting
#
# Overfitting generally occurs when there are a small number of training examples. Data augmentation takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",input_shape=(img_height,img_width,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
# visualizing how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# # Model Building & training on the augmented data :
#
# * Creating a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescaling images to normalize pixel values between (0,1).
# * Choosing an appropriate optimiser and loss function for model training
# * Training the model for ~20 epochs
# * Plotting Graph for findings after the model fit to check if there is any evidence of model overfit or underfit.

# %%
# CNN Model
model=models.Sequential()
# scaling the pixel values from 0-255 to 0-1
model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))

# adding the augmentation layer before the convolution layer
model.add(data_augmentation)

# Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

# Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(9,activation='softmax'))

# %%
# Compiling the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_2 (Conv2D)           (None, 180, 180, 64)      1792
#
#  max_pooling2d_2 (MaxPoolin  (None, 90, 90, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_3 (MaxPoolin  (None, 45, 45, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 259200)            0
#
#  dense_2 (Dense)             (None, 256)               66355456
#
#  dense_3 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 66433417 (253.42 MB)
# Trainable params: 66433417 (253.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Training the model
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 6s 83ms/step - loss: 2.6669 - accuracy: 0.2879 - val_loss: 1.7197 - val_accuracy: 0.3378
# Epoch 2/20
# 56/56 [==============================] - 4s 74ms/step - loss: 1.6858 - accuracy: 0.4012 - val_loss: 1.4762 - val_accuracy: 0.4922
# Epoch 3/20
# 56/56 [==============================] - 4s 73ms/step - loss: 1.4901 - accuracy: 0.4816 - val_loss: 1.6870 - val_accuracy: 0.4273
# Epoch 4/20
# 56/56 [==============================] - 4s 74ms/step - loss: 1.5054 - accuracy: 0.4771 - val_loss: 1.4774 - val_accuracy: 0.5011
# Epoch 5/20
# 56/56 [==============================] - 4s 73ms/step - loss: 1.3606 - accuracy: 0.5128 - val_loss: 1.4204 - val_accuracy: 0.5436
# Epoch 6/20
# 56/56 [==============================] - 4s 73ms/step - loss: 1.3128 - accuracy: 0.5402 - val_loss: 1.4634 - val_accuracy: 0.5168
# Epoch 7/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.2993 - accuracy: 0.5312 - val_loss: 1.5293 - val_accuracy: 0.4765
# Epoch 8/20
# 56/56 [==============================] - 4s 73ms/step - loss: 1.2551 - accuracy: 0.5519 - val_loss: 1.4113 - val_accuracy: 0.5034
# Epoch 9/20
# 56/56 [==============================] - 4s 72ms/step - loss: 1.2316 - accuracy: 0.5586 - val_loss: 1.3823 - val_accuracy: 0.5391
# Epoch 10/20
# 56/56 [==============================] - 4s 80ms/step - loss: 1.2314 - accuracy: 0.5525 - val_loss: 1.3502 - val_accuracy: 0.5257
# Epoch 11/20
# 56/56 [==============================] - 4s 74ms/step - loss: 1.1545 - accuracy: 0.5898 - val_loss: 1.2688 - val_accuracy: 0.5593
# Epoch 12/20
# 56/56 [==============================] - 4s 73ms/step - loss: 1.2535 - accuracy: 0.5513 - val_loss: 1.7742 - val_accuracy: 0.4004
# Epoch 13/20
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2559 - accuracy: 0.5502 - val_loss: 1.3031 - val_accuracy: 0.5481
# Epoch 14/20
# 56/56 [==============================] - 4s 72ms/step - loss: 1.1074 - accuracy: 0.5943 - val_loss: 1.3127 - val_accuracy: 0.5660
# Epoch 15/20
# 56/56 [==============================] - 4s 72ms/step - loss: 1.1085 - accuracy: 0.6133 - val_loss: 1.3263 - val_accuracy: 0.5570
# Epoch 16/20
# 56/56 [==============================] - 4s 75ms/step - loss: 1.0676 - accuracy: 0.5993 - val_loss: 1.3062 - val_accuracy: 0.5503
# Epoch 17/20
# 56/56 [==============================] - 4s 73ms/step - loss: 1.0923 - accuracy: 0.6116 - val_loss: 1.4025 - val_accuracy: 0.5570
# Epoch 18/20
# 56/56 [==============================] - 4s 72ms/step - loss: 1.1168 - accuracy: 0.5993 - val_loss: 1.3346 - val_accuracy: 0.5459
# Epoch 19/20
# 56/56 [==============================] - 4s 74ms/step - loss: 1.0422 - accuracy: 0.6205 - val_loss: 1.3603 - val_accuracy: 0.5794
# Epoch 20/20
# 56/56 [==============================] - 4s 74ms/step - loss: 1.0440 - accuracy: 0.6205 - val_loss: 1.3537 - val_accuracy: 0.5727

# %%
# Visualizing training results
plot_cnn_metrics(history,epochs)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <span style='font-family:Georgia'>
#         <b>Findings : </b>
#         <ol>
#             <li>As the training accuracy increases linearly over time, where as the validation accuracy increases and stall at 55% accuracy in training process.</li>
#             <li>As the training loss decreases with epochs the validation loss decreases and stalls.</li>
#             <li>The plots show that gap between training accuracy and validation accuracy have decreased from previous model, and it has achieved around <b>57%</b> accuracy on the validation set.</li>
#             <li>The difference in accuracy between training and validation accuracy is still <b>slightly noticeable</b> which is a sign of overfitting.</li>
#         </ol>
#     </span>
# </div>

# %% [markdown]
# # Model Building & training on the augmented data with dropout :
#
# * Creating a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescaling images to normalize pixel values between (0,1).
# * Choosing an appropriate optimiser and loss function for model training
# * Training the model for ~20 epochs
# * Plotting Graph for findings after the model fit to check if there is any evidence of model overfit or underfit.

# %%
# CNN Model
model=models.Sequential()
# scaling the pixel values from 0-255 to 0-1
model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))
model.add(data_augmentation)

# Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

# Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())
#adding a 20% dropout after the convolution layers
model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(9,activation='softmax'))

# %%
# Compiling the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 180, 180, 64)      1792
#
#  max_pooling2d_4 (MaxPoolin  (None, 90, 90, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 45, 45, 128)       0
#  g2D)
#
#  dropout (Dropout)           (None, 45, 45, 128)       0
#
#  flatten_2 (Flatten)         (None, 259200)            0
#
#  dense_4 (Dense)             (None, 256)               66355456
#
#  dense_5 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 66433417 (253.42 MB)
# Trainable params: 66433417 (253.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Training the model
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 10s 112ms/step - loss: 3.5979 - accuracy: 0.1998 - val_loss: 1.9012 - val_accuracy: 0.2953
# Epoch 2/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.8321 - accuracy: 0.3209 - val_loss: 1.6832 - val_accuracy: 0.3915
# Epoch 3/20
# 56/56 [==============================] - 6s 109ms/step - loss: 1.6577 - accuracy: 0.4023 - val_loss: 1.5119 - val_accuracy: 0.4810
# Epoch 4/20
# 56/56 [==============================] - 6s 109ms/step - loss: 1.5470 - accuracy: 0.4498 - val_loss: 1.6874 - val_accuracy: 0.4340
# Epoch 5/20
# 56/56 [==============================] - 6s 109ms/step - loss: 1.4642 - accuracy: 0.4777 - val_loss: 1.6736 - val_accuracy: 0.4251
# Epoch 6/20
# 56/56 [==============================] - 6s 110ms/step - loss: 1.4125 - accuracy: 0.4994 - val_loss: 1.5016 - val_accuracy: 0.5011
# Epoch 7/20
# 56/56 [==============================] - 6s 109ms/step - loss: 1.3561 - accuracy: 0.5212 - val_loss: 1.4940 - val_accuracy: 0.5168
# Epoch 8/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.3580 - accuracy: 0.5106 - val_loss: 1.7888 - val_accuracy: 0.3781
# Epoch 9/20
# 56/56 [==============================] - 6s 109ms/step - loss: 1.4105 - accuracy: 0.5067 - val_loss: 1.4787 - val_accuracy: 0.5123
# Epoch 10/20
# 56/56 [==============================] - 6s 108ms/step - loss: 1.2879 - accuracy: 0.5312 - val_loss: 1.4814 - val_accuracy: 0.4899
# Epoch 11/20
# 56/56 [==============================] - 6s 109ms/step - loss: 1.2428 - accuracy: 0.5491 - val_loss: 1.4086 - val_accuracy: 0.5459
# Epoch 12/20
# 56/56 [==============================] - 6s 108ms/step - loss: 1.1947 - accuracy: 0.5714 - val_loss: 1.3333 - val_accuracy: 0.5526
# Epoch 13/20
# 56/56 [==============================] - 6s 108ms/step - loss: 1.2129 - accuracy: 0.5675 - val_loss: 1.3870 - val_accuracy: 0.5280
# Epoch 14/20
# 56/56 [==============================] - 6s 109ms/step - loss: 1.1732 - accuracy: 0.5787 - val_loss: 1.3676 - val_accuracy: 0.5570
# Epoch 15/20
# 56/56 [==============================] - 6s 110ms/step - loss: 1.1470 - accuracy: 0.5843 - val_loss: 1.4094 - val_accuracy: 0.5638
# Epoch 16/20
# 56/56 [==============================] - 6s 109ms/step - loss: 1.1192 - accuracy: 0.6010 - val_loss: 1.3868 - val_accuracy: 0.5190
# Epoch 17/20
# 56/56 [==============================] - 6s 110ms/step - loss: 1.1688 - accuracy: 0.5882 - val_loss: 1.3465 - val_accuracy: 0.5570
# Epoch 18/20
# 56/56 [==============================] - 6s 108ms/step - loss: 1.0654 - accuracy: 0.6110 - val_loss: 1.4290 - val_accuracy: 0.5615
# Epoch 19/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.1017 - accuracy: 0.5971 - val_loss: 1.3848 - val_accuracy: 0.5705
# Epoch 20/20
# 56/56 [==============================] - 6s 108ms/step - loss: 1.0501 - accuracy: 0.6172 - val_loss: 1.3701 - val_accuracy: 0.5682

# %%
# Visualizing training results
plot_cnn_metrics(history,epochs)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <span style='font-family:Georgia'>
#         <b>Findings : </b>
#         <ol>
#             <li>As the training accuracy increases linearly over time, where as the validation accuracy increases and stall at 55% accuracy in training process.</li>
#             <li><b>As the training loss decreases with epochs the validation loss decreases</b></li>
#             <li>The plots show that gap between training accuracy and validation accuracy have decreased from previous model, and it has achieved around <b>55%</b> accuracy on the validation set.</li>
#             <li>The difference in accuracy between training and validation accuracy is <b>very less</b></li>
#         </ol>
#     </span>
# </div>

# %% [markdown]
# ### **We can clearly see that the overfitting of the model has redused significantly when compared the earlier models**

# %% [markdown]
# # Class distribution:
#
# Examining the current class distribution in the training dataset
#
# Datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others.
#
# Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
for i in range(len(class_names)):
  print(class_names[i],' - ',len(list(data_dir_train.glob(class_names[i]+'/*.jpg'))))
# Out:
# actinic keratosis  -  114
# basal cell carcinoma  -  376
# dermatofibroma  -  95
# melanoma  -  438
# nevus  -  357
# pigmented benign keratosis  -  462
# seborrheic keratosis  -  77
# squamous cell carcinoma  -  181
# vascular lesion  -  139

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <span style='font-family:Georgia'>
#         <b>Findings : </b>
#         <ol>
#             <li>Which class has the least number of samples?<br>
#             <b>seborrheic keratosis with 77 samples</b></li>
#             <li>Which classes dominate the data in terms proportionate number of samples?<br>
#             <b>pigmented benign keratosis with 462 samples</b></li>
#         </ol>
#     </span>
# </div>

# %% [markdown]
# # Handling class imbalances:
#
# Rectifing class imbalances present in the training dataset with Augmentor library.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.4)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %%
path_to_training_dataset=data_dir_train

# %%
import Augmentor
import os
for i in class_names:
   output_directory="content/working/melanoma/"+i+"/"
   os.makedirs(output_directory, exist_ok=True)
   #print(str(path_to_training_dataset) +"/"+ i)
   p = Augmentor.Pipeline(str(path_to_training_dataset) +"/"+ i,output_directory="/content/working/melanoma/"+i+"/")
   p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
   p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/working/melanoma/actinic keratosis/.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C400A645270>: 100%|██████████| 500/500 [00:14<00:00, 34.65 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/working/melanoma/basal cell carcinoma/.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C40701BCF70>: 100%|██████████| 500/500 [00:14<00:00, 33.39 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/working/melanoma/dermatofibroma/.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C400ECE7D60>: 100%|██████████| 500/500 [00:17<00:00, 29.29 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/working/melanoma/melanoma/.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7C40702B3E50>: 100%|██████████| 500/500 [01:24<00:00,  5.88 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/working/melanoma/nevus/.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7C400EC49B10>: 100%|██████████| 500/500 [01:13<00:00,  6.82 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/working/melanoma/pigmented benign keratosis/.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C400EE9D600>: 100%|██████████| 500/500 [00:14<00:00, 33.88 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/working/melanoma/seborrheic keratosis/.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7C40702D0070>: 100%|██████████| 500/500 [00:34<00:00, 14.69 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/working/melanoma/squamous cell carcinoma/.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7C400EA28970>: 100%|██████████| 500/500 [00:14<00:00, 34.79 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/working/melanoma/vascular lesion/.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7C400EB413F0>: 100%|██████████| 500/500 [00:14<00:00, 33.77 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train = pathlib.Path("/content/working/melanoma/")
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
lesion_list_new = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]

# %%
dict_new = dict(zip(path_list, lesion_list_new))
df = pd.DataFrame(list(dict_new.items()),columns = ['Path','Label'])

# %%
df['Label'].value_counts()
# Out:
# Label
# dermatofibroma                500
# nevus                         500
# seborrheic keratosis          500
# pigmented benign keratosis    500
# melanoma                      500
# actinic keratosis             500
# vascular lesion               500
# squamous cell carcinoma       500
# basal cell carcinoma          500
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %%
# initializing the parameter to load the images
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# # Model Building & training on the rectified class imbalance data :
#
# * Creating a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescaling images to normalize pixel values between (0,1).
# * Choosing an appropriate optimiser and loss function for model training
# * Training the model for ~30 epochs
# * Plotting Graph for findings after the model fit to check if there is any evidence of model overfit or underfit.

# %%
# CNN Model
model=models.Sequential()
# scaling the pixel values from 0-255 to 0-1
model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))
model.add(data_augmentation)

# Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

# Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())
#adding a 20% dropout after the convolution layers
model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(9,activation='softmax'))

# %%
# Compiling the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 64)      1792
#
#  max_pooling2d_6 (MaxPoolin  (None, 90, 90, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_7 (MaxPoolin  (None, 45, 45, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 45, 45, 128)       0
#
#  flatten_3 (Flatten)         (None, 259200)            0
#
#  dense_6 (Dense)             (None, 256)               66355456
#
#  dense_7 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 66433417 (253.42 MB)
# Trainable params: 66433417 (253.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Training the model
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 113/113 [==============================] - 21s 168ms/step - loss: 2.3680 - accuracy: 0.1964 - val_loss: 1.8423 - val_accuracy: 0.2533
# Epoch 2/30
# 113/113 [==============================] - 18s 149ms/step - loss: 1.6903 - accuracy: 0.3344 - val_loss: 1.6084 - val_accuracy: 0.3578
# Epoch 3/30
# 113/113 [==============================] - 17s 141ms/step - loss: 1.6014 - accuracy: 0.3878 - val_loss: 1.5348 - val_accuracy: 0.4089
# Epoch 4/30
# 113/113 [==============================] - 17s 140ms/step - loss: 1.5001 - accuracy: 0.4264 - val_loss: 1.6027 - val_accuracy: 0.3489
# Epoch 5/30
# 113/113 [==============================] - 17s 143ms/step - loss: 1.4551 - accuracy: 0.4494 - val_loss: 1.3720 - val_accuracy: 0.4500
# Epoch 6/30
# 113/113 [==============================] - 18s 147ms/step - loss: 1.3807 - accuracy: 0.4717 - val_loss: 1.3968 - val_accuracy: 0.4533
# Epoch 7/30
# 113/113 [==============================] - 16s 139ms/step - loss: 1.3660 - accuracy: 0.4747 - val_loss: 1.4512 - val_accuracy: 0.4233
# Epoch 8/30
# 113/113 [==============================] - 16s 138ms/step - loss: 1.3018 - accuracy: 0.5086 - val_loss: 1.3713 - val_accuracy: 0.4689
# Epoch 9/30
# 113/113 [==============================] - 16s 138ms/step - loss: 1.2280 - accuracy: 0.5364 - val_loss: 1.4075 - val_accuracy: 0.4889
# Epoch 10/30
# 113/113 [==============================] - 17s 143ms/step - loss: 1.2324 - accuracy: 0.5289 - val_loss: 1.4011 - val_accuracy: 0.4622
# Epoch 11/30
# 113/113 [==============================] - 18s 147ms/step - loss: 1.1896 - accuracy: 0.5469 - val_loss: 1.2402 - val_accuracy: 0.5278
# Epoch 12/30
# 113/113 [==============================] - 16s 139ms/step - loss: 1.1340 - accuracy: 0.5683 - val_loss: 1.2585 - val_accuracy: 0.5256
# Epoch 13/30
# 113/113 [==============================] - 16s 139ms/step - loss: 1.1162 - accuracy: 0.5775 - val_loss: 1.1477 - val_accuracy: 0.5822
# Epoch 14/30
# 113/113 [==============================] - 19s 162ms/step - loss: 1.0660 - accuracy: 0.5903 - val_loss: 1.1716 - val_accuracy: 0.5722
# Epoch 15/30
# 113/113 [==============================] - 16s 140ms/step - loss: 1.0321 - accuracy: 0.6083 - val_loss: 1.0344 - val_accuracy: 0.6089
# Epoch 16/30
# 113/113 [==============================] - 17s 147ms/step - loss: 1.0330 - accuracy: 0.6161 - val_loss: 1.0326 - val_accuracy: 0.6422
# Epoch 17/30
# 113/113 [==============================] - 16s 139ms/step - loss: 0.9928 - accuracy: 0.6364 - val_loss: 1.1079 - val_accuracy: 0.6144
# Epoch 18/30
# 113/113 [==============================] - 19s 160ms/step - loss: 0.9440 - accuracy: 0.6453 - val_loss: 1.0996 - val_accuracy: 0.6333
# Epoch 19/30
# 113/113 [==============================] - 16s 138ms/step - loss: 0.9744 - accuracy: 0.6411 - val_loss: 0.9987 - val_accuracy: 0.6456
# Epoch 20/30
# 113/113 [==============================] - 17s 142ms/step - loss: 0.8691 - accuracy: 0.6803 - val_loss: 1.1987 - val_accuracy: 0.5756
# Epoch 21/30
# 113/113 [==============================] - 16s 139ms/step - loss: 0.8624 - accuracy: 0.6842 - val_loss: 1.0500 - val_accuracy: 0.6389
# Epoch 22/30
# 113/113 [==============================] - 16s 136ms/step - loss: 0.8111 - accuracy: 0.6989 - val_loss: 0.9573 - val_accuracy: 0.6767
# Epoch 23/30
# 113/113 [==============================] - 16s 138ms/step - loss: 0.7998 - accuracy: 0.7075 - val_loss: 0.9817 - val_accuracy: 0.6744
# Epoch 24/30
# 113/113 [==============================] - 16s 134ms/step - loss: 0.8408 - accuracy: 0.7000 - val_loss: 0.9999 - val_accuracy: 0.6433
# Epoch 25/30
# 113/113 [==============================] - 16s 138ms/step - loss: 0.7675 - accuracy: 0.7158 - val_loss: 1.0780 - val_accuracy: 0.6544
# Epoch 26/30
# 113/113 [==============================] - 17s 141ms/step - loss: 0.7882 - accuracy: 0.7131 - val_loss: 0.9111 - val_accuracy: 0.7022
# Epoch 27/30
# 113/113 [==============================] - 16s 137ms/step - loss: 0.7673 - accuracy: 0.7244 - val_loss: 0.9330 - val_accuracy: 0.7044
# Epoch 28/30
# 113/113 [==============================] - 16s 136ms/step - loss: 0.7018 - accuracy: 0.7436 - val_loss: 0.9347 - val_accuracy: 0.7000
# Epoch 29/30
# 113/113 [==============================] - 16s 138ms/step - loss: 0.6850 - accuracy: 0.7489 - val_loss: 0.8536 - val_accuracy: 0.7289
# Epoch 30/30
# 113/113 [==============================] - 16s 138ms/step - loss: 0.6363 - accuracy: 0.7617 - val_loss: 0.9111 - val_accuracy: 0.6933

# %%
# Visualizing model results
plot_cnn_metrics(history,epochs)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <span style='font-family:Georgia'>
#         <b>Findings : </b>
#         <ol>
#             <li>As the training accuracy increases linearly over time, where as the validation accuracy increases in training process.</li>
#             <li>As the training loss decreases with epochs the validation loss also decreases.</li>
#             <li>The plots show that gap between training accuracy and validation accuracy have decreased significantly from previous model, and it has achieved around <b>75%</b> accuracy on the validation set.</li>
#             <li>The difference in accuracy between training and validation accuracy is <b>very less</b></li>
#         </ol>
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <span style='font-family:Georgia'>
#         <p>Class rebalancing not only got rid of overfitting it also improved the accuracy from 55% to 75%.</p>
#     </span>
# </div>
